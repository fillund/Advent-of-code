# %%
from aocd.models import Puzzle
from typing import Tuple, Dict
from collections import defaultdict, deque
from itertools import combinations
from functools import lru_cache
import re

puzzle = Puzzle(year=2020,day=10)
print(puzzle.input_data)
# Out:
# 71
# 30
# 134
# 33
# 51
# 115
# 122
# 38
# 61
# 103
# 21
# 12
# 44
# 129
# 29
# 89
# 54
# 83
# 96
# 91
# 133
# 102
# 99
# 52
# 144
# 82
# 22
# 68
# 7
# 15
# 93
# 125
# 14
# 92
# 1
# 146
# 67
# 132
# 114
# 59
# 72
# 107
# 34
# 119
# 136
# 60
# 20
# 53
# 8
# 46
# 55
# 26
# 126
# 77
# 65
# 78
# 13
# 108
# 142
# 27
# 75
# 110
# 90
# 35
# 143
# 86
# 116
# 79
# 48
# 113
# 101
# 2
# 123
# 58
# 19
# 76
# 16
# 66
# 135
# 64
# 28
# 9
# 6
# 100
# 124
# 47
# 109
# 23
# 139
# 145
# 5
# 45
# 106
# 41

# %%
adapters = [int(x) for x in puzzle.input_data.splitlines()]
adapters += [max(adapters)+3] + [0]
adapters = sorted(adapters)


diff1 = 0
diff3 = 0
for i, val in enumerate(adapters[:-1]):
    diff = adapters[i+1]-adapters[i]
    if diff == 1:
        diff1 += 1
    elif diff == 3:
        diff3 += 1
    else:
        print(diff, i)
print(diff1, diff3, len(adapters))

answer_a = diff1*(diff3)
# Out:
# 68 27 96

# %%
puzzle.answer_a = answer_a

# %%
def solve_b(dataset: list) -> int:
    n = len(dataset)
    dataset = sorted(dataset)
    DP = {}
    def _rec(idx: int) -> int:
        if idx >= len(dataset)-1:
            return 1
        if idx in DP:
            return DP[idx]
        possible = [_rec(j) for j in range(idx+1,len(dataset)) if dataset[j]-dataset[idx] <= 3]
        DP[idx] = sum(possible)
        return DP[idx]

    return _rec(0)

testdata= """16
10
15
5
1
11
7
19
6
12
4""".splitlines()

testdata2="""28
33
18
42
31
14
46
20
48
47
24
23
49
45
19
38
39
11
1
32
25
35
8
17
7
9
4
2
34
10
3""".splitlines()
testdata = list(map(int, testdata2))
testdata += [0]+[max(testdata) + 3]
answer_b = solve_b(adapters)

# %%
puzzle.answer_b = answer_b
# Out:
# That's the right answer!  You are one gold star closer to saving your vacation.You have completed Day 10! You can [Shareon
#   Twitter
# Mastodon] this victory or [Return to Your Advent Calendar].
